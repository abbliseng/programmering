# %%
header = ["humidity","temperature","room"]

# %%
def unique_vals(rows, col):
    return set([row[col] for row in rows])

# %%
def class_counts(rows):
    counts = {}
    for row in rows:
        label = row[-1]
        if label not in counts:
            counts[label] = 0
        counts[label] += 1
    return counts

# %%
def is_numeric(value):
    return isinstance(value, int) or isinstance(value, float)

# %%
class Question:
    
    def __init__(self, column, value):
        self.column = column
        self.value = value
        
    def match(self, example):
        val = example[self.column]
        if is_numeric(val):
            return val >= self.value
        else:
            return val == self.value
        
    def moreless(self, example):
        val = example[self.column]
        if is_numeric(val):
            return val >= self.value
        else:
            return val <= self.value
    
    def __repr__(self):
        # This is just a helper method to print
        # the question in a readable format.
        condition = "=="
        if is_numeric(self.value):
            condition = ">="
        return "Is %s %s %s?" % (
            header[self.column], condition, str(self.value))

# %%
def partition(rows, question):
    true_rows, false_rows = [], []
    for row in rows:
        if question.match(row):
            true_rows.append(row)
        else:
            false_rows.append(row)
    return true_rows, false_rows

def partitionMoreLess(rows, question):
    true_rows, false_rows = [],[]
    for row in rows:
        if question.moreless(row):
            true_rows.append(row)
        else:
            false_rows.append(row)
    return true_rows, false_rows

# %%
def gini(rows):
    counts = class_counts(rows)
    impurity = 1
    for lbl in counts:
        prob_of_lbl = counts[lbl] / float(len(rows))
        impurity -= prob_of_lbl**2
    return impurity

# %%
def info_gain(left, right, current_uncertainty):
    p = float(len(left))/(len(left)+len(right))
    return current_uncertainty - p * gini(left) - (1 - p) * gini(right)

# %%
def find_best_split(rows):
    best_gain = 0
    best_question = None
    current_uncertainty = gini(rows)
    n_features = len(rows[0]) - 1
    
    for col in range(n_features):
        values = set([row[col] for row in rows])
        for val in values:
            question = Question(col, val)
            true_rows, false_rows = partitionMoreLess(rows, question)
            
            if len(true_rows) == 0 or len(false_rows) == 0:
                continue
            
            gain = info_gain(true_rows, false_rows, current_uncertainty)
            
            if gain > best_gain:
                best_gain, best_question = gain, question
    
    return best_gain, best_question

# %%
class Leaf:
    def __init__(self, rows):
        self.predictions = class_counts(rows)

# %%
class Decision_Node:
    def __init__(self, question, true_branch, false_branch):
        self.question = question
        self.true_branch = true_branch
        self.false_branch = false_branch

# %%
def build_tree(rows):
    gain, question = find_best_split(rows)
    if gain == 0:
        return Leaf(rows)
    true_rows, false_rows = partition(rows, question)
    
    true_branch = build_tree(true_rows)
    false_branch = build_tree(false_rows)
    
    return Decision_Node(question, true_branch, false_branch)

# %%
def print_tree(node, spacing=""):
    if isinstance(node, Leaf):
        print(spacing + "Predict",node.predictions)
        return
    
    print(spacing + str(node.question))
    print(spacing + '--> True:')
    print_tree(node.true_branch, spacing + "  ")
    print(spacing + '--> False:')
    print_tree(node.false_branch, spacing + "  ")

# %%
def classify(row, node):
    """See the 'rules of recursion' above."""

    # Base case: we've reached a leaf
    if isinstance(node, Leaf):
        return node.predictions

    # Decide whether to follow the true-branch or the false-branch.
    # Compare the feature / value stored in the node,
    # to the example we're considering.
    if node.question.match(row):
        return classify(row, node.true_branch)
    else:
        return classify(row, node.false_branch)

# %%
def print_leaf(counts):
    """A nicer way to print the predictions at a leaf."""
    total = sum(counts.values()) * 1.0
    probs = {}
    for lbl in counts.keys():
        probs[lbl] = str(int(counts[lbl] / total * 100)) + "%"
    return probs

# %%
rooms = [
    {"label": "Freezer", "minheat":-10.0, "maxheat": 10.0, "minhum": 5.7, "maxhum":40.9},
    {"label": "Kitchen", "minheat":15.65, "maxheat": 32.10, "minhum": 25, "maxhum":70.2},
    {"label": "Livingroom", "minheat":18.6, "maxheat": 28.0, "minhum": 30.65, "maxhum":65},
    {"label": "Greenhouse", "minheat":30.12, "maxheat": 55.6, "minhum": 38.7, "maxhum":80.98},
]

# %%
import random
import pandas as pd
def GenerateNewData(rooms, nPoints):
    data = []
    for room in rooms:
        if nPoints > 100:
            n = random.randint(nPoints-(nPoints/2),nPoints)
        else:
            n = random.randint(1,nPoints)
        for i in range(0,n):
            t = random.uniform(room["minheat"],room["maxheat"])
            h = random.uniform(room["minhum"], room["maxhum"])
            data.append([h,t,room["label"]])
    print(len(data))
    return data

newdata = GenerateNewData(rooms,1000)
newvalues = pd.DataFrame(newdata)
newvalues[2].value_counts()
# Out:
# 2731
# Livingroom    942
# Kitchen       635
# Greenhouse    624
# Freezer       530
# Name: 2, dtype: int64

# %%
newvalues = newvalues.sample(frac=1).reset_index(drop=True) # Randomizes the array!

# %%
def splitData(data, ntrees, ownvalue):
    subsets = []
    splitOne = data.sample(frac=0.5,random_state=200)
    splitTwo = data.drop(splitOne.index)
    if ntrees != 1:
        fb = splitData(splitOne, ntrees-1, ownvalue+"a")
        fb2 = splitData(splitTwo, ntrees-1, ownvalue+"b")
        for i in range(0,len(fb)):
            subsets.append(fb[i])
            subsets.append(fb2[i])
    else:
        return [splitOne, splitTwo]
    return subsets

# %%
subsets = splitData(newvalues,5,"a")
print("nSubsets:",len(subsets))
print("nValues/subset:",len(subsets[0]))
print(subsets[0])
# Out:
# nSubsets: 32
# nValues/subset: 86
#               0          1           2
# 1401  35.504378  20.678655  Livingroom
# 1148  38.276266  20.874772     Kitchen
# 2602  56.602357  34.371317  Greenhouse
# 372   39.428697  20.687358     Kitchen
# 529   69.837929  19.089643     Kitchen
# ...         ...        ...         ...
# 2565  69.444692  34.801238  Greenhouse
# 356   28.627182  17.781601     Kitchen
# 2094  26.430031  29.849362     Kitchen
# 716   43.211236  26.829672  Livingroom
# 1385  80.083631  36.967069  Greenhouse
#
# [86 rows x 3 columns]

# %%
forrest = []
i = 1
for iSet in subsets:
    iList = iSet.values.tolist()
    i+=1
    tree = build_tree(iList)
    forrest.append(tree)
    print_tree(tree)
# Out:
# Is temperature >= 31.990900829965742?
# --> True:
#   Predict {'Greenhouse': 23}
# --> False:
#   Is temperature >= 15.93598635770735?
#   --> True:
#     Is temperature >= 22.223625399544936?
#     --> True:
#       Is temperature >= 27.42149187166944?
#       --> True:
#         Is humidity >= 51.54174197093124?
#         --> True:
#           Is humidity >= 56.279265767496135?
#           --> True:
#             Predict {'Kitchen': 1}
#           --> False:
#             Predict {'Livingroom': 1}
#         --> False:
#           Predict {'Kitchen': 5}
#       --> False:
#         Is humidity >= 45.51911233783494?
#         --> True:
#           Is humidity >= 63.61078104248174?
#           --> True:
#             Is humidity >= 63.89248707588036?
#             --> True:
#               Predict {'Livingroom': 2}
#             --> False:
#               Predict {'Kitchen': 1}
#           --> False:
#             Predict {'Livingroom': 13}
#         --> False:
#           Is temperature >= 24.30229940620845?
#           --> True:
#             Is temperature >= 26.829671726858592?
#             --> True:
#               Predict {'Livingroom': 1}
#             --> False:
#               Predict {'Kitchen': 2}
#           --> False:
#             Predict {'Livingroom': 2}
#     --> False:
#       Is humidity >= 46.405933508260844?
#       --> True:
#         Predict {'Kitchen': 8}
#       --> False:
#         Is humidity >= 41.815549013335655?
#         --> True:
#           Predict {'Livingroom': 2}
#         --> False:
#           Is temperature >= 21.07849173246234?
#           --> True:
#             Predict {'Livingroom': 1}
#           --> False:
#             Is temperature >= 20.67865460564545?
#             --> True:
#               Is humidity >= 38.27626623364026?
#               --> True:
#                 Predict {'Kitchen': 2}
#               --> False:
#                 Predict {'Livingroom': 1}
#             --> False:
#               Predict {'Kitchen': 4}
#   --> False:
#     Predict {'Freezer': 17}
# Is temperature >= 30.617416893477312?
# --> True:
#   Is humidity >= 42.56469697165646?
#   --> True:
#     Predict {'Greenhouse': 21}
#   --> False:
#     Predict {'Kitchen': 1}
# --> False:
#   Is temperature >= 15.976083645859934?
#   --> True:
#     Is temperature >= 18.743885731736906?
#     --> True:
#       Is humidity >= 30.676819887705285?
#       --> True:
#         Is humidity >= 68.44417282788038?
#         --> True:
#           Predict {'Kitchen': 2}
#         --> False:
#           Is temperature >= 22.409299508773678?
#           --> True:
#             Is temperature >= 23.06046782234655?
#             --> True:
#               Is humidity >= 62.87083086411978?
#               --> True:
#                 Predict {'Kitchen': 1}
#               --> False:
#                 Is temperature >= 25.252450553763733?
#                 --> True:
#                   Is temperature >= 25.823830175481454?
#                   --> True:
#                     Predict {'Livingroom': 7}
#                   --> False:
#                     Predict {'Kitchen': 2}
#                 --> False:
#                   Predict {'Livingroom': 10}
#             --> False:
#               Predict {'Kitchen': 3}
#           --> False:
#             Predict {'Livingroom': 14}
#       --> False:
#         Predict {'Kitchen': 4}
#     --> False:
#       Predict {'Kitchen': 6}
#   --> False:
#     Predict {'Freezer': 14}
# Is temperature >= 30.29609784801605?
# --> True:
#   Is temperature >= 32.30879093376259?
#   --> True:
#     Predict {'Greenhouse': 18}
#   --> False:
#     Is humidity >= 61.17851561136455?
#     --> True:
#       Predict {'Kitchen': 1}
#     --> False:
#       Predict {'Greenhouse': 4}
# --> False:
#   Is temperature >= 17.104580967251454?
#   --> True:
#     Is humidity >= 63.300650038314274?
#     --> True:
#       Predict {'Kitchen': 3}
#     --> False:
#       Is temperature >= 29.974251213818203?
#       --> True:
#         Predict {'Kitchen': 2}
#       --> False:
#         Is humidity >= 47.42812427714?
#         --> True:
#           Is humidity >= 57.78273342234295?
#           --> True:
#             Is humidity >= 57.982812557712975?
#             --> True:
#               Is humidity >= 59.65802538336628?
#               --> True:
#                 Predict {'Livingroom': 3}
#               --> False:
#                 Is humidity >= 59.3026027467823?
#                 --> True:
#                   Predict {'Kitchen': 1}
#                 --> False:
#                   Predict {'Livingroom': 2}
#             --> False:
#               Predict {'Kitchen': 1}
#           --> False:
#             Predict {'Livingroom': 13}
#         --> False:
#           Is humidity >= 40.86729670868134?
#           --> True:
#             Predict {'Kitchen': 6}
#           --> False:
#             Is humidity >= 30.865782605674784?
#             --> True:
#               Is temperature >= 18.604938282777983?
#               --> True:
#                 Is temperature >= 22.48211617212825?
#                 --> True:
#                   Is temperature >= 23.577617417272087?
#                   --> True:
#                     Is humidity >= 37.51861583961269?
#                     --> True:
#                       Predict {'Kitchen': 1}
#                     --> False:
#                       Predict {'Livingroom': 5}
#                   --> False:
#                     Predict {'Kitchen': 1}
#                 --> False:
#                   Predict {'Livingroom': 10}
#               --> False:
#                 Predict {'Kitchen': 1}
#             --> False:
#               Predict {'Kitchen': 1}
#   --> False:
#     Predict {'Freezer': 13}
# Is temperature >= 16.576762588188213?
# --> True:
#   Is temperature >= 32.284163459953746?
#   --> True:
#     Predict {'Greenhouse': 17}
#   --> False:
#     Is temperature >= 28.23079557579804?
#     --> True:
#       Predict {'Kitchen': 5}
#     --> False:
#       Is temperature >= 18.609543266691432?
#       --> True:
#         Is temperature >= 26.120715075664734?
#         --> True:
#           Is temperature >= 26.861153700267273?
#           --> True:
#             Predict {'Livingroom': 4}
#           --> False:
#             Predict {'Kitchen': 3}
#         --> False:
#           Is humidity >= 51.170815976705015?
#           --> True:
#             Predict {'Livingroom': 11}
#           --> False:
#             Is humidity >= 46.766070103539185?
#             --> True:
#               Is temperature >= 22.665542641227162?
#               --> True:
#                 Predict {'Livingroom': 2}
#               --> False:
#                 Predict {'Kitchen': 3}
#             --> False:
#               Is temperature >= 22.18229675900323?
#               --> True:
#                 Is temperature >= 22.373504322841487?
#                 --> True:
#                   Is humidity >= 41.85670124031053?
#                   --> True:
#                     Is humidity >= 44.23221752343201?
#                     --> True:
#                       Predict {'Livingroom': 1}
#                     --> False:
#                       Predict {'Kitchen': 1}
#                   --> False:
#                     Predict {'Livingroom': 7}
#                 --> False:
#                   Predict {'Kitchen': 1}
#               --> False:
#                 Predict {'Livingroom': 11}
#       --> False:
#         Predict {'Kitchen': 2}
# --> False:
#   Predict {'Freezer': 18}
# Is temperature >= 30.54993607595606?
# --> True:
#   Predict {'Greenhouse': 22}
# --> False:
#   Is temperature >= 18.088623988806454?
#   --> True:
#     Is temperature >= 26.83134165864438?
#     --> True:
#       Predict {'Kitchen': 6}
#     --> False:
#       Is humidity >= 31.13275593934062?
#       --> True:
#         Is humidity >= 41.1703459261285?
#         --> True:
#           Is temperature >= 19.125814236950315?
#           --> True:
#             Is humidity >= 68.10631854139302?
#             --> True:
#               Predict {'Kitchen': 1}
#             --> False:
#               Is temperature >= 24.610543434795535?
#               --> True:
#                 Predict {'Livingroom': 6}
#               --> False:
#                 Is humidity >= 59.271820820235234?
#                 --> True:
#                   Predict {'Kitchen': 2}
#                 --> False:
#                   Is temperature >= 22.6401352242047?
#                   --> True:
#                     Is humidity >= 50.43108417256771?
#                     --> True:
#                       Predict {'Kitchen': 2}
#                     --> False:
#                       Is temperature >= 23.22501861633113?
#                       --> True:
#                         Predict {'Livingroom': 3}
#                       --> False:
#                         Predict {'Kitchen': 2}
#                   --> False:
#                     Is humidity >= 53.76345450987897?
#                     --> True:
#                       Predict {'Livingroom': 3}
#                     --> False:
#                       Is humidity >= 52.35453941600255?
#                       --> True:
#                         Predict {'Kitchen': 1}
#                       --> False:
#                         Predict {'Livingroom': 3}
#           --> False:
#             Is humidity >= 62.06126757870032?
#             --> True:
#               Is humidity >= 67.81371704267457?
#               --> True:
#                 Predict {'Kitchen': 1}
#               --> False:
#                 Predict {'Livingroom': 1}
#             --> False:
#               Predict {'Kitchen': 3}
#         --> False:
#           Predict {'Livingroom': 7}
#       --> False:
#         Predict {'Kitchen': 2}
#   --> False:
#     Predict {'Freezer': 20}
# Is temperature >= 31.136354897800555?
# --> True:
#   Predict {'Greenhouse': 19}
# --> False:
#   Is temperature >= 17.18469119820878?
#   --> True:
#     Is temperature >= 26.27432837462082?
#     --> True:
#       Is humidity >= 57.457603825770114?
#       --> True:
#         Is humidity >= 68.73645374643073?
#         --> True:
#           Predict {'Kitchen': 1}
#         --> False:
#           Predict {'Livingroom': 2}
#       --> False:
#         Is humidity >= 38.75113690001556?
#         --> True:
#           Predict {'Kitchen': 7}
#         --> False:
#           Is humidity >= 34.5589122366553?
#           --> True:
#             Is temperature >= 29.810335666459814?
#             --> True:
#               Predict {'Kitchen': 1}
#             --> False:
#               Predict {'Livingroom': 2}
#           --> False:
#             Predict {'Kitchen': 3}
#     --> False:
#       Is temperature >= 19.133391631543407?
#       --> True:
#         Is humidity >= 68.6701763734183?
#         --> True:
#           Predict {'Kitchen': 2}
#         --> False:
#           Is temperature >= 25.777180650997146?
#           --> True:
#             Is humidity >= 51.72967163156502?
#             --> True:
#               Predict {'Livingroom': 2}
#             --> False:
#               Predict {'Kitchen': 2}
#           --> False:
#             Is temperature >= 21.169264413795503?
#             --> True:
#               Predict {'Livingroom': 14}
#             --> False:
#               Is humidity >= 53.563923977089786?
#               --> True:
#                 Predict {'Kitchen': 2}
#               --> False:
#                 Is temperature >= 20.15300993064722?
#                 --> True:
#                   Is temperature >= 20.555509674637054?
#                   --> True:
#                     Predict {'Livingroom': 2}
#                   --> False:
#                     Predict {'Kitchen': 2}
#                 --> False:
#                   Predict {'Livingroom': 6}
#       --> False:
#         Predict {'Kitchen': 4}
#   --> False:
#     Predict {'Freezer': 14}
# Is temperature >= 31.097639732795628?
# --> True:
#   Predict {'Greenhouse': 19}
# --> False:
#   Is temperature >= 16.499821858222738?
#   --> True:
#     Is temperature >= 27.962081983286154?
#     --> True:
#       Predict {'Kitchen': 5}
#     --> False:
#       Is humidity >= 31.95553557146826?
#       --> True:
#         Is temperature >= 18.661485800875028?
#         --> True:
#           Is humidity >= 51.610945693147585?
#           --> True:
#             Is temperature >= 26.637628969884894?
#             --> True:
#               Predict {'Kitchen': 1}
#             --> False:
#               Predict {'Livingroom': 14}
#           --> False:
#             Is humidity >= 50.66603746217875?
#             --> True:
#               Predict {'Kitchen': 1}
#             --> False:
#               Is temperature >= 25.008805794352515?
#               --> True:
#                 Is temperature >= 25.938846169081213?
#                 --> True:
#                   Is humidity >= 36.72441704234129?
#                   --> True:
#                     Predict {'Livingroom': 3}
#                   --> False:
#                     Is humidity >= 36.38170665094118?
#                     --> True:
#                       Predict {'Kitchen': 1}
#                     --> False:
#                       Predict {'Livingroom': 3}
#                 --> False:
#                   Predict {'Kitchen': 2}
#               --> False:
#                 Is temperature >= 20.63910210858863?
#                 --> True:
#                   Predict {'Livingroom': 10}
#                 --> False:
#                   Is humidity >= 37.4301279337569?
#                   --> True:
#                     Is temperature >= 20.5231764275363?
#                     --> True:
#                       Predict {'Kitchen': 1}
#                     --> False:
#                       Predict {'Livingroom': 4}
#                   --> False:
#                     Predict {'Kitchen': 1}
#         --> False:
#           Predict {'Kitchen': 3}
#       --> False:
#         Predict {'Kitchen': 3}
#   --> False:
#     Predict {'Freezer': 14}
# Is temperature >= 15.762026951247615?
# --> True:
#   Is temperature >= 31.44279861006392?
#   --> True:
#     Is temperature >= 32.89291944621389?
#     --> True:
#       Predict {'Greenhouse': 15}
#     --> False:
#       Is humidity >= 45.61658425877157?
#       --> True:
#         Predict {'Kitchen': 1}
#       --> False:
#         Predict {'Greenhouse': 1}
#   --> False:
#     Is temperature >= 28.006815891268175?
#     --> True:
#       Predict {'Kitchen': 5}
#     --> False:
#       Is temperature >= 22.451549485097573?
#       --> True:
#         Is humidity >= 54.47439506478172?
#         --> True:
#           Predict {'Livingroom': 9}
#         --> False:
#           Is humidity >= 45.83026227607256?
#           --> True:
#             Is humidity >= 52.20821392186903?
#             --> True:
#               Is humidity >= 54.317373107772966?
#               --> True:
#                 Predict {'Kitchen': 1}
#               --> False:
#                 Predict {'Livingroom': 2}
#             --> False:
#               Predict {'Kitchen': 2}
#           --> False:
#             Is temperature >= 26.99502723002722?
#             --> True:
#               Is temperature >= 27.07280441770498?
#               --> True:
#                 Predict {'Livingroom': 3}
#               --> False:
#                 Predict {'Kitchen': 1}
#             --> False:
#               Predict {'Livingroom': 9}
#       --> False:
#         Is temperature >= 20.87534978735834?
#         --> True:
#           Is humidity >= 42.21861117321319?
#           --> True:
#             Is humidity >= 50.95372761991982?
#             --> True:
#               Predict {'Kitchen': 2}
#             --> False:
#               Predict {'Livingroom': 1}
#           --> False:
#             Predict {'Kitchen': 2}
#         --> False:
#           Is temperature >= 18.747012677724804?
#           --> True:
#             Is humidity >= 48.11957415806266?
#             --> True:
#               Predict {'Livingroom': 5}
#             --> False:
#               Is humidity >= 35.46249981514163?
#               --> True:
#                 Predict {'Kitchen': 2}
#               --> False:
#                 Predict {'Livingroom': 2}
#           --> False:
#             Predict {'Kitchen': 2}
# --> False:
#   Predict {'Freezer': 20}
# Is temperature >= 31.420762366511134?
# --> True:
#   Predict {'Greenhouse': 31}
# --> False:
#   Is temperature >= 15.89402726448631?
#   --> True:
#     Is temperature >= 18.931536001165085?
#     --> True:
#       Is temperature >= 28.921534588743405?
#       --> True:
#         Predict {'Kitchen': 3}
#       --> False:
#         Is humidity >= 47.10909316483712?
#         --> True:
#           Is humidity >= 67.67566699333966?
#           --> True:
#             Predict {'Kitchen': 1}
#           --> False:
#             Is humidity >= 54.053389440959066?
#             --> True:
#               Predict {'Livingroom': 9}
#             --> False:
#               Is humidity >= 52.822417706635875?
#               --> True:
#                 Predict {'Kitchen': 1}
#               --> False:
#                 Predict {'Livingroom': 5}
#         --> False:
#           Is temperature >= 22.70742053424779?
#           --> True:
#             Is temperature >= 27.313819648490107?
#             --> True:
#               Predict {'Livingroom': 2}
#             --> False:
#               Is humidity >= 46.27406566083493?
#               --> True:
#                 Predict {'Livingroom': 1}
#               --> False:
#                 Is humidity >= 40.60876731099693?
#                 --> True:
#                   Predict {'Kitchen': 4}
#                 --> False:
#                   Is humidity >= 39.54964535846498?
#                   --> True:
#                     Predict {'Livingroom': 1}
#                   --> False:
#                     Is humidity >= 35.963141458624996?
#                     --> True:
#                       Is humidity >= 37.59577327015252?
#                       --> True:
#                         Predict {'Kitchen': 1}
#                       --> False:
#                         Predict {'Livingroom': 1}
#                     --> False:
#                       Predict {'Kitchen': 1}
#           --> False:
#             Is humidity >= 46.49405823207708?
#             --> True:
#               Predict {'Kitchen': 1}
#             --> False:
#               Predict {'Livingroom': 5}
#     --> False:
#       Predict {'Kitchen': 5}
#   --> False:
#     Predict {'Freezer': 14}
# Is temperature >= 16.845623550944048?
# --> True:
#   Is temperature >= 31.672605929032954?
#   --> True:
#     Predict {'Greenhouse': 13}
#   --> False:
#     Is temperature >= 27.122572536957684?
#     --> True:
#       Is temperature >= 28.05340648492806?
#       --> True:
#         Predict {'Kitchen': 5}
#       --> False:
#         Is humidity >= 44.733746801259315?
#         --> True:
#           Predict {'Kitchen': 2}
#         --> False:
#           Predict {'Livingroom': 1}
#     --> False:
#       Is humidity >= 59.39934795795868?
#       --> True:
#         Is temperature >= 23.356132285781015?
#         --> True:
#           Is temperature >= 24.00644008961416?
#           --> True:
#             Predict {'Kitchen': 2}
#           --> False:
#             Predict {'Livingroom': 3}
#         --> False:
#           Predict {'Kitchen': 4}
#       --> False:
#         Is humidity >= 31.126466546573408?
#         --> True:
#           Is temperature >= 18.618192263034743?
#           --> True:
#             Is temperature >= 23.079297014099826?
#             --> True:
#               Predict {'Livingroom': 18}
#             --> False:
#               Is temperature >= 22.740065229486603?
#               --> True:
#                 Predict {'Kitchen': 1}
#               --> False:
#                 Is temperature >= 20.3624065720493?
#                 --> True:
#                   Is temperature >= 22.138809572718998?
#                   --> True:
#                     Is temperature >= 22.242869455098774?
#                     --> True:
#                       Predict {'Livingroom': 3}
#                     --> False:
#                       Predict {'Kitchen': 1}
#                   --> False:
#                     Predict {'Livingroom': 7}
#                 --> False:
#                   Is humidity >= 47.11506048647266?
#                   --> True:
#                     Is temperature >= 20.16645832975629?
#                     --> True:
#                       Predict {'Kitchen': 1}
#                     --> False:
#                       Predict {'Livingroom': 4}
#                   --> False:
#                     Predict {'Kitchen': 1}
#           --> False:
#             Predict {'Kitchen': 1}
#         --> False:
#           Predict {'Kitchen': 1}
# --> False:
#   Predict {'Freezer': 18}
# Is temperature >= 32.09152328073939?
# --> True:
#   Predict {'Greenhouse': 18}
# --> False:
#   Is temperature >= 16.514060842538292?
#   --> True:
#     Is temperature >= 27.961342504582312?
#     --> True:
#       Predict {'Kitchen': 11}
#     --> False:
#       Is humidity >= 32.556022544081195?
#       --> True:
#         Is temperature >= 20.601879984551495?
#         --> True:
#           Is humidity >= 66.37892385787966?
#           --> True:
#             Predict {'Kitchen': 1}
#           --> False:
#             Is temperature >= 21.167241725734566?
#             --> True:
#               Is humidity >= 34.75230031833316?
#               --> True:
#                 Is humidity >= 54.379745648225914?
#                 --> True:
#                   Is humidity >= 56.156670655573635?
#                   --> True:
#                     Is temperature >= 26.080370042295314?
#                     --> True:
#                       Is temperature >= 26.48905016835102?
#                       --> True:
#                         Predict {'Livingroom': 3}
#                       --> False:
#                         Predict {'Kitchen': 1}
#                     --> False:
#                       Predict {'Livingroom': 7}
#                   --> False:
#                     Predict {'Kitchen': 1}
#                 --> False:
#                   Predict {'Livingroom': 11}
#               --> False:
#                 Is humidity >= 34.461847659560156?
#                 --> True:
#                   Predict {'Kitchen': 1}
#                 --> False:
#                   Predict {'Livingroom': 2}
#             --> False:
#               Is humidity >= 44.818151233086816?
#               --> True:
#                 Predict {'Livingroom': 3}
#               --> False:
#                 Is humidity >= 35.889059259406906?
#                 --> True:
#                   Predict {'Kitchen': 2}
#                 --> False:
#                   Predict {'Livingroom': 1}
#         --> False:
#           Is humidity >= 47.80251188028484?
#           --> True:
#             Is humidity >= 50.88692582833251?
#             --> True:
#               Is humidity >= 64.28019826621963?
#               --> True:
#                 Predict {'Livingroom': 1}
#               --> False:
#                 Predict {'Kitchen': 2}
#             --> False:
#               Predict {'Livingroom': 2}
#           --> False:
#             Predict {'Kitchen': 3}
#       --> False:
#         Predict {'Kitchen': 3}
#   --> False:
#     Predict {'Freezer': 13}
# Is temperature >= 30.93583457280518?
# --> True:
#   Is temperature >= 32.95278806321382?
#   --> True:
#     Predict {'Greenhouse': 25}
#   --> False:
#     Is humidity >= 61.54797479980978?
#     --> True:
#       Predict {'Greenhouse': 3}
#     --> False:
#       Predict {'Kitchen': 2}
# --> False:
#   Is temperature >= 16.608267991729576?
#   --> True:
#     Is temperature >= 29.203471793112342?
#     --> True:
#       Predict {'Kitchen': 5}
#     --> False:
#       Is humidity >= 61.398311298504275?
#       --> True:
#         Predict {'Kitchen': 4}
#       --> False:
#         Is temperature >= 21.48380519934565?
#         --> True:
#           Is humidity >= 45.301743367568676?
#           --> True:
#             Is humidity >= 49.70299677373475?
#             --> True:
#               Predict {'Livingroom': 11}
#             --> False:
#               Predict {'Kitchen': 3}
#           --> False:
#             Predict {'Livingroom': 12}
#         --> False:
#           Is humidity >= 45.98261122371226?
#           --> True:
#             Is humidity >= 57.11792160961596?
#             --> True:
#               Predict {'Kitchen': 1}
#             --> False:
#               Predict {'Livingroom': 1}
#           --> False:
#             Predict {'Kitchen': 1}
#   --> False:
#     Predict {'Freezer': 18}
# Is temperature >= 30.33438667852945?
# --> True:
#   Is humidity >= 39.71893345197868?
#   --> True:
#     Predict {'Greenhouse': 19}
#   --> False:
#     Predict {'Kitchen': 1}
# --> False:
#   Is temperature >= 15.859763581065106?
#   --> True:
#     Is humidity >= 32.29200736115553?
#     --> True:
#       Is humidity >= 62.42011513058173?
#       --> True:
#         Predict {'Kitchen': 4}
#       --> False:
#         Is temperature >= 29.109230890560717?
#         --> True:
#           Predict {'Kitchen': 2}
#         --> False:
#           Is humidity >= 38.68936578472638?
#           --> True:
#             Is temperature >= 18.741040375303363?
#             --> True:
#               Is humidity >= 46.19703633167629?
#               --> True:
#                 Is humidity >= 51.42272419591545?
#                 --> True:
#                   Predict {'Livingroom': 10}
#                 --> False:
#                   Is temperature >= 21.909985168262676?
#                   --> True:
#                     Predict {'Kitchen': 2}
#                   --> False:
#                     Predict {'Livingroom': 1}
#               --> False:
#                 Predict {'Livingroom': 14}
#             --> False:
#               Predict {'Kitchen': 1}
#           --> False:
#             Is humidity >= 34.42842384311981?
#             --> True:
#               Is temperature >= 22.000743922027866?
#               --> True:
#                 Predict {'Kitchen': 5}
#               --> False:
#                 Is humidity >= 37.84122582571762?
#                 --> True:
#                   Predict {'Kitchen': 1}
#                 --> False:
#                   Predict {'Livingroom': 3}
#             --> False:
#               Predict {'Livingroom': 3}
#     --> False:
#       Predict {'Kitchen': 4}
#   --> False:
#     Predict {'Freezer': 16}
# Is temperature >= 16.145094677974896?
# --> True:
#   Is temperature >= 31.49392193866629?
#   --> True:
#     Is temperature >= 32.446344543336124?
#     --> True:
#       Predict {'Greenhouse': 16}
#     --> False:
#       Is humidity >= 62.15548546171745?
#       --> True:
#         Predict {'Greenhouse': 2}
#       --> False:
#         Predict {'Kitchen': 2}
#   --> False:
#     Is temperature >= 28.649356800135727?
#     --> True:
#       Predict {'Kitchen': 6}
#     --> False:
#       Is humidity >= 64.72614078842463?
#       --> True:
#         Predict {'Kitchen': 3}
#       --> False:
#         Is temperature >= 18.765447112110767?
#         --> True:
#           Is temperature >= 21.40800757819252?
#           --> True:
#             Is temperature >= 23.820092869742076?
#             --> True:
#               Is humidity >= 58.88001198511522?
#               --> True:
#                 Predict {'Kitchen': 1}
#               --> False:
#                 Is humidity >= 44.58260263061478?
#                 --> True:
#                   Predict {'Livingroom': 8}
#                 --> False:
#                   Is humidity >= 43.9095524599622?
#                   --> True:
#                     Predict {'Kitchen': 1}
#                   --> False:
#                     Is temperature >= 25.289656917153764?
#                     --> True:
#                       Is humidity >= 42.052551375116366?
#                       --> True:
#                         Predict {'Livingroom': 1}
#                       --> False:
#                         Is humidity >= 35.56518056493581?
#                         --> True:
#                           Predict {'Kitchen': 2}
#                         --> False:
#                           Predict {'Livingroom': 1}
#                     --> False:
#                       Predict {'Livingroom': 4}
#             --> False:
#               Is humidity >= 42.094823685929185?
#               --> True:
#                 Predict {'Kitchen': 3}
#               --> False:
#                 Is humidity >= 39.049130662432944?
#                 --> True:
#                   Predict {'Livingroom': 2}
#                 --> False:
#                   Predict {'Kitchen': 1}
#           --> False:
#             Predict {'Livingroom': 9}
#         --> False:
#           Predict {'Kitchen': 3}
# --> False:
#   Predict {'Freezer': 21}
# Is temperature >= 30.138338225169097?
# --> True:
#   Is humidity >= 40.402810386121104?
#   --> True:
#     Is temperature >= 31.56870845678603?
#     --> True:
#       Predict {'Greenhouse': 20}
#     --> False:
#       Is humidity >= 57.2096345124632?
#       --> True:
#         Predict {'Greenhouse': 3}
#       --> False:
#         Predict {'Kitchen': 1}
#   --> False:
#     Predict {'Kitchen': 1}
# --> False:
#   Is temperature >= 15.725589183182045?
#   --> True:
#     Is temperature >= 18.68871552358524?
#     --> True:
#       Is temperature >= 29.708076726690983?
#       --> True:
#         Predict {'Kitchen': 1}
#       --> False:
#         Is humidity >= 59.15238234642792?
#         --> True:
#           Predict {'Livingroom': 6}
#         --> False:
#           Is humidity >= 58.66723652282676?
#           --> True:
#             Predict {'Kitchen': 1}
#           --> False:
#             Is temperature >= 27.04531544758433?
#             --> True:
#               Predict {'Livingroom': 4}
#             --> False:
#               Is temperature >= 26.594908482060674?
#               --> True:
#                 Predict {'Kitchen': 1}
#               --> False:
#                 Is humidity >= 33.6260700096518?
#                 --> True:
#                   Is humidity >= 36.824130140386?
#                   --> True:
#                     Is temperature >= 25.272942490067358?
#                     --> True:
#                       Is temperature >= 26.066244672164455?
#                       --> True:
#                         Predict {'Livingroom': 2}
#                       --> False:
#                         Predict {'Kitchen': 2}
#                     --> False:
#                       Is humidity >= 52.21253310060244?
#                       --> True:
#                         Predict {'Livingroom': 5}
#                       --> False:
#                         Is humidity >= 51.11688966962282?
#                         --> True:
#                           Predict {'Kitchen': 2}
#                         --> False:
#                           Is humidity >= 41.46115295008753?
#                           --> True:
#                             Predict {'Livingroom': 5}
#                           --> False:
#                             Is humidity >= 40.276343252510344?
#                             --> True:
#                               Predict {'Kitchen': 1}
#                             --> False:
#                               Is humidity >= 39.55510933059003?
#                               --> True:
#                                 Is humidity >= 39.76181596882596?
#                                 --> True:
#                                   Predict {'Livingroom': 2}
#                                 --> False:
#                                   Predict {'Kitchen': 1}
#                               --> False:
#                                 Predict {'Livingroom': 3}
#                   --> False:
#                     Predict {'Kitchen': 1}
#                 --> False:
#                   Predict {'Livingroom': 3}
#     --> False:
#       Predict {'Kitchen': 7}
#   --> False:
#     Predict {'Freezer': 14}
# Is temperature >= 15.934443672086605?
# --> True:
#   Is temperature >= 36.09746455946881?
#   --> True:
#     Predict {'Greenhouse': 13}
#   --> False:
#     Is temperature >= 28.53113803205838?
#     --> True:
#       Predict {'Kitchen': 8}
#     --> False:
#       Is temperature >= 19.56613124166397?
#       --> True:
#         Is humidity >= 67.81885994851055?
#         --> True:
#           Predict {'Kitchen': 2}
#         --> False:
#           Is temperature >= 24.947468898607248?
#           --> True:
#             Is temperature >= 27.41789494829657?
#             --> True:
#               Is humidity >= 59.66951115849663?
#               --> True:
#                 Predict {'Livingroom': 1}
#               --> False:
#                 Predict {'Kitchen': 1}
#             --> False:
#               Is temperature >= 26.24709118931194?
#               --> True:
#                 Is temperature >= 26.449625503498332?
#                 --> True:
#                   Predict {'Livingroom': 4}
#                 --> False:
#                   Predict {'Kitchen': 1}
#               --> False:
#                 Predict {'Livingroom': 8}
#           --> False:
#             Is temperature >= 20.275797601343143?
#             --> True:
#               Is humidity >= 64.73607640115173?
#               --> True:
#                 Predict {'Livingroom': 2}
#               --> False:
#                 Is humidity >= 59.15296413388014?
#                 --> True:
#                   Is humidity >= 64.26459349164365?
#                   --> True:
#                     Is humidity >= 64.56068317268574?
#                     --> True:
#                       Predict {'Kitchen': 1}
#                     --> False:
#                       Predict {'Livingroom': 1}
#                   --> False:
#                     Predict {'Kitchen': 3}
#                 --> False:
#                   Is humidity >= 40.22828566252597?
#                   --> True:
#                     Is humidity >= 47.73419676502455?
#                     --> True:
#                       Is humidity >= 58.9697044034975?
#                       --> True:
#                         Predict {'Livingroom': 2}
#                       --> False:
#                         Is humidity >= 50.55890114605458?
#                         --> True:
#                           Predict {'Kitchen': 2}
#                         --> False:
#                           Is humidity >= 48.01475071346252?
#                           --> True:
#                             Predict {'Livingroom': 1}
#                           --> False:
#                             Predict {'Kitchen': 1}
#                     --> False:
#                       Predict {'Livingroom': 5}
#                   --> False:
#                     Is humidity >= 34.497876196316184?
#                     --> True:
#                       Predict {'Kitchen': 2}
#                     --> False:
#                       Is humidity >= 34.16188587918637?
#                       --> True:
#                         Predict {'Livingroom': 1}
#                       --> False:
#                         Is humidity >= 31.245947874786005?
#                         --> True:
#                           Is humidity >= 31.918756015214093?
#                           --> True:
#                             Predict {'Kitchen': 1}
#                           --> False:
#                             Predict {'Livingroom': 1}
#                         --> False:
#                           Predict {'Kitchen': 1}
#             --> False:
#               Predict {'Livingroom': 4}
#       --> False:
#         Is humidity >= 61.152097679059835?
#         --> True:
#           Is humidity >= 62.785436585026886?
#           --> True:
#             Predict {'Kitchen': 2}
#           --> False:
#             Predict {'Livingroom': 1}
#         --> False:
#           Predict {'Kitchen': 4}
# --> False:
#   Predict {'Freezer': 13}
# Is temperature >= 30.22376745687974?
# --> True:
#   Is temperature >= 34.0350738970983?
#   --> True:
#     Predict {'Greenhouse': 22}
#   --> False:
#     Is humidity >= 47.28724678772373?
#     --> True:
#       Predict {'Kitchen': 3}
#     --> False:
#       Predict {'Greenhouse': 3}
# --> False:
#   Is temperature >= 15.669537335926108?
#   --> True:
#     Is temperature >= 18.64447899514175?
#     --> True:
#       Is humidity >= 32.9219019425613?
#       --> True:
#         Is temperature >= 30.06546706661028?
#         --> True:
#           Predict {'Kitchen': 1}
#         --> False:
#           Is humidity >= 61.75133398782266?
#           --> True:
#             Is humidity >= 64.00965525036848?
#             --> True:
#               Predict {'Livingroom': 1}
#             --> False:
#               Is humidity >= 62.73087142219109?
#               --> True:
#                 Is humidity >= 62.88853716785309?
#                 --> True:
#                   Predict {'Kitchen': 1}
#                 --> False:
#                   Predict {'Livingroom': 1}
#               --> False:
#                 Predict {'Kitchen': 1}
#           --> False:
#             Is humidity >= 35.50008311559081?
#             --> True:
#               Is temperature >= 23.362967534326273?
#               --> True:
#                 Is temperature >= 23.417217355152687?
#                 --> True:
#                   Is temperature >= 24.217313606361245?
#                   --> True:
#                     Predict {'Livingroom': 11}
#                   --> False:
#                     Is temperature >= 23.810812714851163?
#                     --> True:
#                       Predict {'Kitchen': 1}
#                     --> False:
#                       Predict {'Livingroom': 2}
#                 --> False:
#                   Predict {'Kitchen': 1}
#               --> False:
#                 Predict {'Livingroom': 15}
#             --> False:
#               Is humidity >= 33.54535529573263?
#               --> True:
#                 Predict {'Kitchen': 1}
#               --> False:
#                 Predict {'Livingroom': 1}
#       --> False:
#         Predict {'Kitchen': 2}
#     --> False:
#       Predict {'Kitchen': 3}
#   --> False:
#     Predict {'Freezer': 15}
# Is temperature >= 15.83787662100788?
# --> True:
#   Is temperature >= 30.290681359105456?
#   --> True:
#     Is humidity >= 61.645591914468866?
#     --> True:
#       Predict {'Greenhouse': 9}
#     --> False:
#       Is humidity >= 59.85175236993106?
#       --> True:
#         Predict {'Kitchen': 2}
#       --> False:
#         Predict {'Greenhouse': 3}
#   --> False:
#     Is humidity >= 31.563053898942847?
#     --> True:
#       Is humidity >= 59.64976721218377?
#       --> True:
#         Is temperature >= 23.335418661283477?
#         --> True:
#           Is humidity >= 62.31608246319779?
#           --> True:
#             Is humidity >= 63.90144514232651?
#             --> True:
#               Predict {'Kitchen': 2}
#             --> False:
#               Predict {'Livingroom': 1}
#           --> False:
#             Predict {'Kitchen': 3}
#         --> False:
#           Predict {'Livingroom': 2}
#       --> False:
#         Is temperature >= 22.40009528293051?
#         --> True:
#           Is humidity >= 35.701756969420295?
#           --> True:
#             Predict {'Livingroom': 23}
#           --> False:
#             Is humidity >= 32.80849356158645?
#             --> True:
#               Predict {'Kitchen': 1}
#             --> False:
#               Predict {'Livingroom': 4}
#         --> False:
#           Is humidity >= 44.04585932795257?
#           --> True:
#             Is humidity >= 47.5487179175273?
#             --> True:
#               Is temperature >= 19.246501537664237?
#               --> True:
#                 Is temperature >= 20.59081659157874?
#                 --> True:
#                   Predict {'Kitchen': 1}
#                 --> False:
#                   Is humidity >= 48.670868859727236?
#                   --> True:
#                     Predict {'Livingroom': 3}
#                   --> False:
#                     Is humidity >= 47.5763871606418?
#                     --> True:
#                       Predict {'Kitchen': 1}
#                     --> False:
#                       Predict {'Livingroom': 1}
#               --> False:
#                 Predict {'Kitchen': 1}
#             --> False:
#               Predict {'Kitchen': 4}
#           --> False:
#             Predict {'Livingroom': 3}
#     --> False:
#       Predict {'Kitchen': 3}
# --> False:
#   Predict {'Freezer': 18}
# Is temperature >= 32.239948317679854?
# --> True:
#   Predict {'Greenhouse': 16}
# --> False:
#   Is temperature >= 16.556121781840492?
#   --> True:
#     Is temperature >= 27.36171821419649?
#     --> True:
#       Is humidity >= 54.268335633165144?
#       --> True:
#         Predict {'Kitchen': 6}
#       --> False:
#         Is humidity >= 48.127637751647235?
#         --> True:
#           Predict {'Greenhouse': 1}
#         --> False:
#           Predict {'Kitchen': 3}
#     --> False:
#       Is humidity >= 65.47326923664852?
#       --> True:
#         Predict {'Kitchen': 3}
#       --> False:
#         Is humidity >= 31.071765476701618?
#         --> True:
#           Is temperature >= 22.990460382987894?
#           --> True:
#             Is temperature >= 25.1551904166299?
#             --> True:
#               Is humidity >= 39.14590588936025?
#               --> True:
#                 Predict {'Livingroom': 6}
#               --> False:
#                 Is humidity >= 38.32985443153366?
#                 --> True:
#                   Predict {'Kitchen': 1}
#                 --> False:
#                   Predict {'Livingroom': 2}
#             --> False:
#               Is humidity >= 33.92412996848072?
#               --> True:
#                 Is humidity >= 45.68278521609845?
#                 --> True:
#                   Is humidity >= 55.71140515468204?
#                   --> True:
#                     Is humidity >= 57.575417061203275?
#                     --> True:
#                       Predict {'Kitchen': 2}
#                     --> False:
#                       Is humidity >= 57.09497300359951?
#                       --> True:
#                         Predict {'Livingroom': 1}
#                       --> False:
#                         Predict {'Kitchen': 2}
#                   --> False:
#                     Predict {'Livingroom': 1}
#                 --> False:
#                   Predict {'Kitchen': 3}
#               --> False:
#                 Predict {'Livingroom': 1}
#           --> False:
#             Is humidity >= 44.94362802350482?
#             --> True:
#               Predict {'Livingroom': 14}
#             --> False:
#               Is humidity >= 43.33893356137152?
#               --> True:
#                 Predict {'Kitchen': 2}
#               --> False:
#                 Is humidity >= 32.64785439236302?
#                 --> True:
#                   Predict {'Livingroom': 3}
#                 --> False:
#                   Is humidity >= 32.23610643986147?
#                   --> True:
#                     Predict {'Kitchen': 1}
#                   --> False:
#                     Predict {'Livingroom': 1}
#         --> False:
#           Predict {'Kitchen': 2}
#   --> False:
#     Predict {'Freezer': 14}
# Is temperature >= 34.208657064391126?
# --> True:
#   Predict {'Greenhouse': 15}
# --> False:
#   Is temperature >= 16.213024473781296?
#   --> True:
#     Is temperature >= 28.053904836920623?
#     --> True:
#       Predict {'Kitchen': 5}
#     --> False:
#       Is temperature >= 18.608708041619433?
#       --> True:
#         Is humidity >= 30.942336718265388?
#         --> True:
#           Is temperature >= 24.845758039790883?
#           --> True:
#             Predict {'Livingroom': 14}
#           --> False:
#             Is temperature >= 24.708875932896383?
#             --> True:
#               Predict {'Kitchen': 2}
#             --> False:
#               Is humidity >= 36.03361780757457?
#               --> True:
#                 Is temperature >= 19.367103875516325?
#                 --> True:
#                   Is humidity >= 45.81316435246889?
#                   --> True:
#                     Predict {'Livingroom': 15}
#                   --> False:
#                     Is humidity >= 42.50191981303334?
#                     --> True:
#                       Predict {'Kitchen': 1}
#                     --> False:
#                       Is temperature >= 22.23142549502315?
#                       --> True:
#                         Is temperature >= 22.841942219261696?
#                         --> True:
#                           Predict {'Livingroom': 2}
#                         --> False:
#                           Predict {'Kitchen': 2}
#                       --> False:
#                         Predict {'Livingroom': 5}
#                 --> False:
#                   Is humidity >= 52.322923515877946?
#                   --> True:
#                     Predict {'Kitchen': 2}
#                   --> False:
#                     Predict {'Livingroom': 2}
#               --> False:
#                 Predict {'Kitchen': 1}
#         --> False:
#           Predict {'Kitchen': 2}
#       --> False:
#         Predict {'Kitchen': 5}
#   --> False:
#     Predict {'Freezer': 12}
# Is temperature >= 30.4025460479245?
# --> True:
#   Is temperature >= 31.14766143587033?
#   --> True:
#     Predict {'Greenhouse': 23}
#   --> False:
#     Is humidity >= 56.47454785725385?
#     --> True:
#       Predict {'Kitchen': 1}
#     --> False:
#       Predict {'Greenhouse': 1}
# --> False:
#   Is temperature >= 15.98055664507344?
#   --> True:
#     Is temperature >= 18.775537724770224?
#     --> True:
#       Is temperature >= 25.129128741599704?
#       --> True:
#         Is humidity >= 48.66755965919147?
#         --> True:
#           Is humidity >= 59.52581331495701?
#           --> True:
#             Predict {'Kitchen': 2}
#           --> False:
#             Predict {'Livingroom': 2}
#         --> False:
#           Is humidity >= 45.863416123323795?
#           --> True:
#             Predict {'Kitchen': 3}
#           --> False:
#             Is humidity >= 45.14579266975731?
#             --> True:
#               Predict {'Livingroom': 1}
#             --> False:
#               Predict {'Kitchen': 2}
#       --> False:
#         Is humidity >= 30.750371281750404?
#         --> True:
#           Is humidity >= 62.442493502194544?
#           --> True:
#             Is temperature >= 24.83920669964975?
#             --> True:
#               Predict {'Livingroom': 1}
#             --> False:
#               Predict {'Kitchen': 2}
#           --> False:
#             Is temperature >= 20.447845577802276?
#             --> True:
#               Is humidity >= 51.416533658147515?
#               --> True:
#                 Is humidity >= 54.66631685508085?
#                 --> True:
#                   Predict {'Livingroom': 6}
#                 --> False:
#                   Predict {'Kitchen': 1}
#               --> False:
#                 Predict {'Livingroom': 13}
#             --> False:
#               Is temperature >= 19.542753629595985?
#               --> True:
#                 Is humidity >= 53.810394791101004?
#                 --> True:
#                   Predict {'Livingroom': 1}
#                 --> False:
#                   Predict {'Kitchen': 3}
#               --> False:
#                 Predict {'Livingroom': 4}
#         --> False:
#           Predict {'Kitchen': 2}
#     --> False:
#       Predict {'Kitchen': 4}
#   --> False:
#     Predict {'Freezer': 13}
# Is temperature >= 18.65676255392334?
# --> True:
#   Is temperature >= 29.547172103513518?
#   --> True:
#     Is temperature >= 32.38287178313646?
#     --> True:
#       Predict {'Greenhouse': 13}
#     --> False:
#       Is temperature >= 31.119433005098575?
#       --> True:
#         Is temperature >= 31.452534422574686?
#         --> True:
#           Predict {'Kitchen': 3}
#         --> False:
#           Predict {'Greenhouse': 3}
#       --> False:
#         Predict {'Kitchen': 4}
#   --> False:
#     Is humidity >= 65.4025993120043?
#     --> True:
#       Predict {'Kitchen': 2}
#     --> False:
#       Is humidity >= 42.31413088066609?
#       --> True:
#         Is humidity >= 63.99508064484293?
#         --> True:
#           Is humidity >= 64.39533571688452?
#           --> True:
#             Predict {'Livingroom': 2}
#           --> False:
#             Predict {'Kitchen': 1}
#         --> False:
#           Is temperature >= 26.428187093490898?
#           --> True:
#             Is temperature >= 26.737040461579472?
#             --> True:
#               Predict {'Livingroom': 2}
#             --> False:
#               Predict {'Kitchen': 1}
#           --> False:
#             Is temperature >= 20.187265365694138?
#             --> True:
#               Predict {'Livingroom': 20}
#             --> False:
#               Is temperature >= 19.876944437134874?
#               --> True:
#                 Predict {'Kitchen': 1}
#               --> False:
#                 Predict {'Livingroom': 6}
#       --> False:
#         Is temperature >= 20.585954573335396?
#         --> True:
#           Is humidity >= 34.81651556582547?
#           --> True:
#             Predict {'Livingroom': 2}
#           --> False:
#             Is humidity >= 34.18259484637919?
#             --> True:
#               Predict {'Kitchen': 1}
#             --> False:
#               Predict {'Livingroom': 2}
#         --> False:
#           Predict {'Kitchen': 2}
# --> False:
#   Predict {'Freezer': 20}
# Is temperature >= 30.702842463095394?
# --> True:
#   Is humidity >= 39.82831655990491?
#   --> True:
#     Is temperature >= 32.258239157676854?
#     --> True:
#       Predict {'Greenhouse': 17}
#     --> False:
#       Is temperature >= 31.783875664966097?
#       --> True:
#         Predict {'Kitchen': 1}
#       --> False:
#         Predict {'Greenhouse': 3}
#   --> False:
#     Predict {'Kitchen': 1}
# --> False:
#   Is temperature >= 17.75395748288138?
#   --> True:
#     Is humidity >= 30.688775751726777?
#     --> True:
#       Is humidity >= 64.59365665785074?
#       --> True:
#         Predict {'Kitchen': 2}
#       --> False:
#         Is temperature >= 19.48897320874626?
#         --> True:
# ...
#             --> False:
#               Predict {'Greenhouse': 2}
#         --> False:
#           Predict {'Kitchen': 4}
#       --> False:
#         Is temperature >= 24.305787970897164?
#         --> True:
#           Is temperature >= 25.75620940248719?
#           --> True:
#             Is humidity >= 33.9522138927102?
#             --> True:
#               Predict {'Livingroom': 5}
#             --> False:
#               Is humidity >= 32.252761593465934?
#               --> True:
#                 Predict {'Kitchen': 1}
#               --> False:
#                 Predict {'Livingroom': 1}
#           --> False:
#             Is humidity >= 53.31958829184596?
#             --> True:
#               Is humidity >= 68.82763065541205?
#               --> True:
#                 Predict {'Kitchen': 1}
#               --> False:
#                 Predict {'Livingroom': 2}
#             --> False:
#               Predict {'Kitchen': 6}
#         --> False:
#           Is temperature >= 19.87627900320383?
#           --> True:
#             Is temperature >= 22.94652842074681?
#             --> True:
#               Is temperature >= 23.160574792953717?
#               --> True:
#                 Predict {'Livingroom': 4}
#               --> False:
#                 Predict {'Kitchen': 1}
#             --> False:
#               Predict {'Livingroom': 11}
#           --> False:
#             Is temperature >= 19.218640001682783?
#             --> True:
#               Predict {'Kitchen': 2}
#             --> False:
#               Predict {'Livingroom': 1}
#     --> False:
#       Predict {'Kitchen': 7}
#   --> False:
#     Predict {'Freezer': 13}
# Is temperature >= 16.417590501759193?
# --> True:
#   Is temperature >= 31.212098073334875?
#   --> True:
#     Predict {'Greenhouse': 17}
#   --> False:
#     Is humidity >= 34.21165588938997?
#     --> True:
#       Is humidity >= 50.32389416626289?
#       --> True:
#         Is humidity >= 64.51959711255728?
#         --> True:
#           Predict {'Kitchen': 4}
#         --> False:
#           Is humidity >= 63.53814775011088?
#           --> True:
#             Predict {'Livingroom': 2}
#           --> False:
#             Is humidity >= 61.81205982244826?
#             --> True:
#               Predict {'Kitchen': 3}
#             --> False:
#               Is humidity >= 58.55474583476098?
#               --> True:
#                 Is humidity >= 61.51266483734028?
#                 --> True:
#                   Is humidity >= 61.687320163646405?
#                   --> True:
#                     Predict {'Livingroom': 1}
#                   --> False:
#                     Predict {'Kitchen': 1}
#                 --> False:
#                   Predict {'Livingroom': 3}
#               --> False:
#                 Is humidity >= 55.99131553638607?
#                 --> True:
#                   Predict {'Kitchen': 4}
#                 --> False:
#                   Is humidity >= 51.93351162636413?
#                   --> True:
#                     Predict {'Livingroom': 2}
#                   --> False:
#                     Predict {'Kitchen': 2}
#       --> False:
#         Is temperature >= 20.216837197457586?
#         --> True:
#           Is humidity >= 42.48677550659385?
#           --> True:
#             Is humidity >= 43.465581881927456?
#             --> True:
#               Is temperature >= 25.56700946632995?
#               --> True:
#                 Is temperature >= 26.368024216750477?
#                 --> True:
#                   Predict {'Livingroom': 2}
#                 --> False:
#                   Predict {'Kitchen': 1}
#               --> False:
#                 Predict {'Livingroom': 4}
#             --> False:
#               Predict {'Kitchen': 1}
#           --> False:
#             Predict {'Livingroom': 11}
#         --> False:
#           Predict {'Kitchen': 1}
#     --> False:
#       Predict {'Kitchen': 5}
# --> False:
#   Predict {'Freezer': 21}
# Is temperature >= 31.631907140650824?
# --> True:
#   Is humidity >= 44.004458049662304?
#   --> True:
#     Predict {'Greenhouse': 20}
#   --> False:
#     Predict {'Kitchen': 1}
# --> False:
#   Is temperature >= 15.747200514079847?
#   --> True:
#     Is humidity >= 60.24375440529776?
#     --> True:
#       Is humidity >= 64.98898553887868?
#       --> True:
#         Is humidity >= 66.46895554048571?
#         --> True:
#           Predict {'Kitchen': 3}
#         --> False:
#           Predict {'Livingroom': 1}
#       --> False:
#         Predict {'Kitchen': 5}
#     --> False:
#       Is temperature >= 28.882144718291265?
#       --> True:
#         Predict {'Kitchen': 3}
#       --> False:
#         Is humidity >= 41.46320184222081?
#         --> True:
#           Is humidity >= 48.47903249839565?
#           --> True:
#             Predict {'Livingroom': 11}
#           --> False:
#             Is temperature >= 21.941000995681097?
#             --> True:
#               Is temperature >= 27.10436499679713?
#               --> True:
#                 Predict {'Livingroom': 1}
#               --> False:
#                 Predict {'Kitchen': 6}
#             --> False:
#               Is temperature >= 18.873469795659148?
#               --> True:
#                 Predict {'Livingroom': 4}
#               --> False:
#                 Predict {'Kitchen': 1}
#         --> False:
#           Predict {'Livingroom': 11}
#   --> False:
#     Predict {'Freezer': 18}
# Is temperature >= 15.951333775282045?
# --> True:
#   Is temperature >= 34.11111159501112?
#   --> True:
#     Predict {'Greenhouse': 17}
#   --> False:
#     Is temperature >= 27.961984167171295?
#     --> True:
#       Predict {'Kitchen': 7}
#     --> False:
#       Is temperature >= 19.217354239325783?
#       --> True:
#         Is temperature >= 26.649645229467176?
#         --> True:
#           Predict {'Livingroom': 5}
#         --> False:
#           Is temperature >= 20.753668245520217?
#           --> True:
#             Is temperature >= 20.987531705013687?
#             --> True:
#               Is humidity >= 31.242862865539713?
#               --> True:
#                 Is humidity >= 39.06846254842857?
#                 --> True:
#                   Is humidity >= 47.97981049154545?
#                   --> True:
#                     Is humidity >= 55.47677862503738?
#                     --> True:
#                       Is humidity >= 60.85902912630388?
#                       --> True:
#                         Is humidity >= 68.34936884953487?
#                         --> True:
#                           Predict {'Kitchen': 1}
#                         --> False:
#                           Predict {'Livingroom': 4}
#                       --> False:
#                         Predict {'Kitchen': 3}
#                     --> False:
#                       Predict {'Livingroom': 7}
#                   --> False:
#                     Is temperature >= 22.453108088461725?
#                     --> True:
#                       Predict {'Kitchen': 4}
#                     --> False:
#                       Predict {'Livingroom': 1}
#                 --> False:
#                   Predict {'Livingroom': 4}
#               --> False:
#                 Predict {'Kitchen': 1}
#             --> False:
#               Predict {'Kitchen': 2}
#           --> False:
#             Predict {'Livingroom': 5}
#       --> False:
#         Predict {'Kitchen': 2}
# --> False:
#   Predict {'Freezer': 22}
# Is temperature >= 35.40128991723493?
# --> True:
#   Predict {'Greenhouse': 22}
# --> False:
#   Is temperature >= 15.817885205087249?
#   --> True:
#     Is temperature >= 27.754270745728576?
#     --> True:
#       Is humidity >= 71.93801060918658?
#       --> True:
#         Predict {'Greenhouse': 1}
#       --> False:
#         Predict {'Kitchen': 8}
#     --> False:
#       Is temperature >= 18.708295322766528?
#       --> True:
#         Is humidity >= 32.62298343774106?
#         --> True:
#           Is humidity >= 64.63000472167226?
#           --> True:
#             Predict {'Kitchen': 1}
#           --> False:
#             Is temperature >= 21.188134605092866?
#             --> True:
#               Predict {'Livingroom': 16}
#             --> False:
#               Is temperature >= 19.614360582171358?
#               --> True:
#                 Is humidity >= 41.30684706403569?
#                 --> True:
#                   Is humidity >= 50.018756191262995?
#                   --> True:
#                     Is temperature >= 20.018133722669212?
#                     --> True:
#                       Predict {'Livingroom': 2}
#                     --> False:
#                       Predict {'Kitchen': 1}
#                   --> False:
#                     Predict {'Kitchen': 3}
#                 --> False:
#                   Predict {'Livingroom': 2}
#               --> False:
#                 Predict {'Livingroom': 6}
#         --> False:
#           Predict {'Kitchen': 2}
#       --> False:
#         Predict {'Kitchen': 5}
#   --> False:
#     Predict {'Freezer': 16}
# Is temperature >= 16.011460107270274?
# --> True:
#   Is temperature >= 30.128609442592307?
#   --> True:
#     Is temperature >= 31.92320064361685?
#     --> True:
#       Predict {'Greenhouse': 14}
#     --> False:
#       Is humidity >= 70.46235884948399?
#       --> True:
#         Predict {'Greenhouse': 2}
#       --> False:
#         Is humidity >= 67.14695285784856?
#         --> True:
#           Predict {'Kitchen': 3}
#         --> False:
#           Is temperature >= 31.345978251016614?
#           --> True:
#             Predict {'Kitchen': 1}
#           --> False:
#             Predict {'Greenhouse': 2}
#   --> False:
#     Is humidity >= 66.35849734167493?
#     --> True:
#       Predict {'Kitchen': 5}
#     --> False:
#       Is temperature >= 18.943362937142222?
#       --> True:
#         Is temperature >= 25.198629945713833?
#         --> True:
#           Is temperature >= 25.935589142556335?
#           --> True:
#             Is temperature >= 29.99222156525841?
#             --> True:
#               Predict {'Kitchen': 1}
#             --> False:
#               Is humidity >= 45.30703341141977?
#               --> True:
#                 Is humidity >= 56.836056965508575?
#                 --> True:
#                   Predict {'Livingroom': 2}
#                 --> False:
#                   Is temperature >= 26.31640573695732?
#                   --> True:
#                     Predict {'Kitchen': 2}
#                   --> False:
#                     Predict {'Livingroom': 1}
#               --> False:
#                 Predict {'Livingroom': 2}
#           --> False:
#             Predict {'Kitchen': 2}
#         --> False:
#           Is humidity >= 33.071767559866316?
#           --> True:
#             Is humidity >= 40.74096884183714?
#             --> True:
#               Predict {'Livingroom': 19}
#             --> False:
#               Is humidity >= 40.738918286777434?
#               --> True:
#                 Predict {'Kitchen': 1}
#               --> False:
#                 Predict {'Livingroom': 4}
#           --> False:
#             Predict {'Kitchen': 1}
#       --> False:
#         Predict {'Kitchen': 4}
# --> False:
#   Predict {'Freezer': 19}
# Is temperature >= 30.428590312843898?
# --> True:
#   Is temperature >= 33.22906922009775?
#   --> True:
#     Predict {'Greenhouse': 14}
#   --> False:
#     Is temperature >= 32.02565786850849?
#     --> True:
#       Predict {'Kitchen': 1}
#     --> False:
#       Is temperature >= 31.03023766594964?
#       --> True:
#         Is humidity >= 58.881827923105945?
#         --> True:
#           Predict {'Kitchen': 1}
#         --> False:
#           Predict {'Greenhouse': 2}
#       --> False:
#         Predict {'Greenhouse': 3}
# --> False:
#   Is temperature >= 16.011292521228228?
#   --> True:
#     Is humidity >= 64.7373209613796?
#     --> True:
#       Predict {'Kitchen': 6}
#     --> False:
#       Is temperature >= 18.70175517242959?
#       --> True:
#         Is temperature >= 27.987536381368095?
#         --> True:
#           Predict {'Kitchen': 2}
#         --> False:
#           Is humidity >= 37.06580505486906?
#           --> True:
#             Is temperature >= 22.892769633541576?
#             --> True:
#               Predict {'Livingroom': 18}
#             --> False:
#               Is temperature >= 22.75955587009121?
#               --> True:
#                 Predict {'Kitchen': 1}
#               --> False:
#                 Predict {'Livingroom': 11}
#           --> False:
#             Is temperature >= 24.63533857578248?
#             --> True:
#               Predict {'Livingroom': 2}
#             --> False:
#               Is temperature >= 18.777549177809014?
#               --> True:
#                 Is humidity >= 33.743504065216726?
#                 --> True:
#                   Is humidity >= 36.876010241661874?
#                   --> True:
#                     Predict {'Kitchen': 1}
#                   --> False:
#                     Predict {'Livingroom': 1}
#                 --> False:
#                   Predict {'Kitchen': 2}
#               --> False:
#                 Predict {'Livingroom': 1}
#       --> False:
#         Predict {'Kitchen': 4}
#   --> False:
#     Predict {'Freezer': 15}
# Is temperature >= 16.25334928269302?
# --> True:
#   Is temperature >= 34.042150787538326?
#   --> True:
#     Predict {'Greenhouse': 16}
#   --> False:
#     Is temperature >= 19.147229506895602?
#     --> True:
#       Is temperature >= 28.549023673402434?
#       --> True:
#         Predict {'Kitchen': 6}
#       --> False:
#         Is humidity >= 46.824880723394635?
#         --> True:
#           Is humidity >= 65.58348177671098?
#           --> True:
#             Predict {'Kitchen': 2}
#           --> False:
#             Is temperature >= 23.626462336339024?
#             --> True:
#               Is humidity >= 56.37282444974828?
#               --> True:
#                 Predict {'Livingroom': 3}
#               --> False:
#                 Is humidity >= 50.43008109659303?
#                 --> True:
#                   Predict {'Kitchen': 2}
#                 --> False:
#                   Predict {'Livingroom': 1}
#             --> False:
#               Predict {'Livingroom': 16}
#         --> False:
#           Is humidity >= 41.37736943231019?
#           --> True:
#             Predict {'Kitchen': 3}
#           --> False:
#             Is humidity >= 33.0733261163667?
#             --> True:
#               Is temperature >= 26.150527859395844?
#               --> True:
#                 Is humidity >= 35.57041565807034?
#                 --> True:
#                   Predict {'Livingroom': 1}
#                 --> False:
#                   Predict {'Kitchen': 1}
#               --> False:
#                 Predict {'Livingroom': 4}
#             --> False:
#               Predict {'Kitchen': 2}
#     --> False:
#       Predict {'Kitchen': 6}
# --> False:
#   Predict {'Freezer': 22}
# Is temperature >= 15.888338465293891?
# --> True:
#   Is temperature >= 30.26555254650163?
#   --> True:
#     Is humidity >= 38.964427736747304?
#     --> True:
#       Is temperature >= 31.026359483707324?
#       --> True:
#         Predict {'Greenhouse': 18}
#       --> False:
#         Is temperature >= 30.99761857748326?
#         --> True:
#           Predict {'Kitchen': 1}
#         --> False:
#           Predict {'Greenhouse': 2}
#     --> False:
#       Predict {'Kitchen': 1}
#   --> False:
#     Is temperature >= 19.234470864877057?
#     --> True:
#       Is temperature >= 28.080505813535417?
#       --> True:
#         Predict {'Kitchen': 4}
#       --> False:
#         Is humidity >= 57.858172702691206?
#         --> True:
#           Is temperature >= 22.657528337719683?
#           --> True:
#             Predict {'Livingroom': 2}
#           --> False:
#             Predict {'Kitchen': 5}
#         --> False:
#           Is humidity >= 33.347232137285744?
#           --> True:
#             Is temperature >= 22.034035884715202?
#             --> True:
#               Predict {'Livingroom': 16}
#             --> False:
#               Is temperature >= 21.545293061472?
#               --> True:
#                 Predict {'Kitchen': 2}
#               --> False:
#                 Is humidity >= 52.37035871294316?
#                 --> True:
#                   Is humidity >= 56.998293543669206?
#                   --> True:
#                     Predict {'Livingroom': 1}
#                   --> False:
#                     Predict {'Kitchen': 1}
#                 --> False:
#                   Predict {'Livingroom': 6}
#           --> False:
#             Predict {'Kitchen': 1}
#     --> False:
#       Predict {'Kitchen': 6}
# --> False:
#   Predict {'Freezer': 19}

# %%
def predictionCounter(row,trees,labels):
    length = len(labels)
    predictions = [0 for i in range(length)]
    for tree in trees:
        prediction = classify(row,tree)
        for i in range(length):
            if(prediction.get(labels[i])is not None):
                predictions[i]+=1
    return predictions

# %%
def rndForest(trees,data):
    for row in data:
        predictions = [0,0,0,0]
        labels = ["Livingroom", "Kitchen", "Greenhouse", "Freezer"]
        predictions = predictionCounter(row, trees, labels)
        high = max(predictions)
        print("Actual:",row[2],labels[predictions.index(high)],":", max(predictions),"/",len(trees))

# %%
testing_data = GenerateNewData(rooms, 1)
#testing_data = testing_data.sample(frac=1).reset_index(drop=True) # Randomizes the array!
# Out:
# 4

# %%
rndForest(forrest,testing_data)
# Out:
# Actual: Freezer Freezer : 32 / 32
# Actual: Kitchen Livingroom : 25 / 32
# Actual: Livingroom Kitchen : 23 / 32
# Actual: Greenhouse Greenhouse : 29 / 32
